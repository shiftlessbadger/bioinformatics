# %% [markdown]
# <a id="anchor"></a>
# # Jupiter Notebook for Brock Kuhlman
# ## *Jan 24, 2024*

# %% [markdown]
# #### Problem 1
#
# > A car with a full tank of gas drives 80 miles per hour for 3 hours before running out of gas. How many miles can the car go per tank?

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mpt = 80*3

# %%
print("The car can drive {} miles per tank.".format(mpt))
# Out:
# The car can drive 240 miles per tank.

# %% [markdown]
# #### To do list
# - [x] make variables
# - [x] create formula
# - [x] create plot

# %%
mile_marker = np.linspace(mpt, 0, 12)
mile_marker = [round(num) for num in mile_marker]
tank_level = [round(num/240, 2) for num in mile_marker]

# %%
# Create the plot
plt.figure(figsize=(8, 6))  # Adjust figure size for better clarity
plt.plot(mile_marker, tank_level[::-1])

# Add labels and title
plt.xlabel("Miles Driven")
plt.ylabel("Tank Level")
plt.title("Tank level per mile driven")

# Show the plot
plt.show()

# %% [markdown]
# #### Problem 2
#
# > A runner travels a half marathon (13.1 miles) in 3 hours. How fast was this runner going in miles per hour?

# %%
mph = round(13.1/3,3)
print("The runner was running {} miles per hour.".format(mph))
# Out:
# The runner was running 4.367 miles per hour.

# %% [markdown]
# ||Mile 1|Mile 2|Mile 3|
# |:----|:----:|:----:|----:|
# |Speed|4.367|4.367|4.367|

# %% [markdown]
# ![20140824-0300.jpg](attachment:85f04f60-207b-438b-9327-92624a98d648.jpg)

# %% [markdown]
# #### Problem 3
#
# > The spread of a virus is exponential. If 5 people are infected and each person infects 2 other people, how many people have been infected after 5 rounds of infection?

# %%
rounds = 5
infection_rate = 2
initial_infected = 5
total_infected = initial_infected*infection_rate**rounds
print('The total number of infected people is {}'.format(total_infected))
# Out:
# The total number of infected people is 160

# %%
round_num = np.linspace(1,rounds,100)
ramp_infected = [initial_infected*infection_rate**num for num in round_num]

# %%
# Create the plot
plt.figure(figsize=(8, 6))  # Adjust figure size for better clarity
plt.plot(round_num, ramp_infected)

# Add labels and title
plt.xlabel("Infection rounds")
plt.ylabel("Infected people")
plt.title("Total infections per infection round")

# Show the plot
plt.show()

# %% [markdown]
# [Go to anchor](#anchor)
